# %%
# sử dung TF_IDF để chuyển đổi

# %%
import pandas as pd

# %%
df = pd.read_csv("/Users/trungdungle/Downloads/laptop final - Trang tính1.csv")

# %%
df.head()
# Out:
#                                                links  \
# 0  Add to CompareASUS Vivobook Go 15 (2023) AMD R...
# 1  Add to CompareASUS TUF Gaming F17 - AI Powered...
# 2  Add to CompareASUS Vivobook 15 Intel Core i3 1...
# 3  Add to CompareASUS Vivobook 15 AMD Ryzen 7 Oct...
# 4  Add to CompareASUS VivoBook 15 (2022) Intel Ce...
#
#                                           links-href  \
# 0  https://www.flipkart.com/asus-vivobook-go-15-2...
# 1  https://www.flipkart.com/asus-tuf-gaming-f17-a...
# 2  https://www.flipkart.com/asus-vivobook-15-inte...
# 3  https://www.flipkart.com/asus-vivobook-15-amd-...
# 4  https://www.flipkart.com/asus-vivobook-15-2022...
#
#                                          picture-src  \
# 0  https://rukminim2.flixcart.com/image/416/416/x...
# 1  https://rukminim2.flixcart.com/image/416/416/x...
# 2  https://rukminim2.flixcart.com/image/416/416/x...
# 3  https://rukminim2.flixcart.com/image/416/416/x...
# ...

# %%
df.shape
# Out:
# (998, 24)
